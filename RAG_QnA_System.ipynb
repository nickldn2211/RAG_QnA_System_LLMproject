# %% [markdown]
# <a href="https://colab.research.google.com/github/nickldn2211/RAG_QnA_System_LLMproject/blob/main/RAG_QnA_System.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Import necessary libraries and modules

# %%
# !pip install streamlit
# !pip install faiss-cpu
# !pip install langchain
# !pip install langchain_huggingface
# !pip install langchain_community

import streamlit as st
import faiss
import os
from io import BytesIO
import numpy as np
from langchain.chains import RetrievalQA
from langchain.text_splitter import CharacterTextSplitter
from langchain_huggingface import HuggingFaceEmbeddings
from langchain_community.vectorstores import FAISS
from langchain_community.docstore.in_memory import InMemoryDocstore
from langchain_huggingface import HuggingFaceEndpoint

# %% [markdown]
# # Set up HuggingFace API token for authentication

# %%
from google.colab import userdata
os.environ['HUGGINGFACEHUB_API_TOKEN'] = userdata.get('GeminiAPI')
